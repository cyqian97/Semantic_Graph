# %%
# %conda install pytorch torchvision torchaudio cudatoolkit=11.3 -c pytorch
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda
#
#   added / updated specs:
#     - cudatoolkit=11.3
#     - pytorch
#     - torchaudio
#     - torchvision
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-4.5          |       2_kmp_llvm           6 KB  conda-forge
#     blas-2.115                 |              mkl          13 KB  conda-forge
#     blas-devel-3.9.0           |   15_linux64_mkl          12 KB  conda-forge
#     cudatoolkit-11.3.1         |      h9edb442_10       816.4 MB  conda-forge
#     ffmpeg-4.3                 |       hf484d3e_0         9.9 MB  pytorch
#     freetype-2.10.4            |       h0708190_1         890 KB  conda-forge
#     giflib-5.2.1               |       h36c2ea0_2          77 KB  conda-forge
#     gmp-6.2.1                  |       h58526e2_0         806 KB  conda-forge
#     gnutls-3.6.13              |       h85f3911_1         2.0 MB  conda-forge
#     jpeg-9e                    |       h166bdaf_2         269 KB  conda-forge
#     lame-3.100                 |    h7f98852_1001         496 KB  conda-forge
#     lcms2-2.12                 |       hddcbb42_0         443 KB  conda-forge
#     lerc-3.0                   |       h9c3ff4c_0         216 KB  conda-forge
#     libblas-3.9.0              |   15_linux64_mkl          13 KB  conda-forge
#     libcblas-3.9.0             |   15_linux64_mkl          12 KB  conda-forge
#     libdeflate-1.12            |       h166bdaf_0          78 KB  conda-forge
#     libgfortran-ng-12.1.0      |      h69a702a_16          23 KB  conda-forge
#     libgfortran5-12.1.0        |      hdcd56e2_16         1.8 MB  conda-forge
#     liblapack-3.9.0            |   15_linux64_mkl          12 KB  conda-forge
#     liblapacke-3.9.0           |   15_linux64_mkl          12 KB  conda-forge
#     libpng-1.6.37              |       h753d276_3         331 KB  conda-forge
#     libtiff-4.4.0              |       hc85c160_1         638 KB  conda-forge
#     libwebp-1.2.3              |       h522a892_0          96 KB  conda-forge
#     libwebp-base-1.2.3         |       h166bdaf_0         452 KB  conda-forge
#     libxcb-1.13                |    h7f98852_1004         391 KB  conda-forge
#     llvm-openmp-14.0.4         |       he0ac6c6_0         5.8 MB  conda-forge
#     mkl-2022.1.0               |     h84fe81f_915       199.6 MB  conda-forge
#     mkl-devel-2022.1.0         |     ha770c72_916          25 KB  conda-forge
#     mkl-include-2022.1.0       |     h84fe81f_915         745 KB  conda-forge
#     nettle-3.6                 |       he412f7d_0         6.5 MB  conda-forge
#     numpy-1.23.1               |  py310h53a5b5f_0         7.0 MB  conda-forge
#     openh264-2.1.1             |       h780b84a_0         1.5 MB  conda-forge
#     openjpeg-2.4.0             |       hb52868f_1         444 KB  conda-forge
#     pillow-9.2.0               |  py310he619898_0        44.7 MB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pytorch-1.12.0             |py3.10_cuda11.3_cudnn8.3.2_0        1.19 GB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     tbb-2021.5.0               |       h924138e_1         1.9 MB  conda-forge
#     torchaudio-0.12.0          |      py310_cu113         6.2 MB  pytorch
#     torchvision-0.13.0         |      py310_cu113        28.3 MB  pytorch
#     typing_extensions-4.3.0    |     pyha770c72_0          28 KB  conda-forge
#     xorg-libxau-1.0.9          |       h7f98852_0          13 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        2.31 GB
#
# The following NEW packages will be INSTALLED:
#
#   blas               conda-forge/linux-64::blas-2.115-mkl
#   blas-devel         conda-forge/linux-64::blas-devel-3.9.0-15_linux64_mkl
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.3.1-h9edb442_10
#   ffmpeg             pytorch/linux-64::ffmpeg-4.3-hf484d3e_0
#   freetype           conda-forge/linux-64::freetype-2.10.4-h0708190_1
#   giflib             conda-forge/linux-64::giflib-5.2.1-h36c2ea0_2
#   gmp                conda-forge/linux-64::gmp-6.2.1-h58526e2_0
#   gnutls             conda-forge/linux-64::gnutls-3.6.13-h85f3911_1
#   jpeg               conda-forge/linux-64::jpeg-9e-h166bdaf_2
#   lame               conda-forge/linux-64::lame-3.100-h7f98852_1001
#   lcms2              conda-forge/linux-64::lcms2-2.12-hddcbb42_0
#   lerc               conda-forge/linux-64::lerc-3.0-h9c3ff4c_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-15_linux64_mkl
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-15_linux64_mkl
#   libdeflate         conda-forge/linux-64::libdeflate-1.12-h166bdaf_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-12.1.0-h69a702a_16
#   libgfortran5       conda-forge/linux-64::libgfortran5-12.1.0-hdcd56e2_16
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-15_linux64_mkl
#   liblapacke         conda-forge/linux-64::liblapacke-3.9.0-15_linux64_mkl
#   libpng             conda-forge/linux-64::libpng-1.6.37-h753d276_3
#   libtiff            conda-forge/linux-64::libtiff-4.4.0-hc85c160_1
#   libwebp            conda-forge/linux-64::libwebp-1.2.3-h522a892_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.2.3-h166bdaf_0
#   libxcb             conda-forge/linux-64::libxcb-1.13-h7f98852_1004
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-14.0.4-he0ac6c6_0
#   mkl                conda-forge/linux-64::mkl-2022.1.0-h84fe81f_915
#   mkl-devel          conda-forge/linux-64::mkl-devel-2022.1.0-ha770c72_916
#   mkl-include        conda-forge/linux-64::mkl-include-2022.1.0-h84fe81f_915
#   nettle             conda-forge/linux-64::nettle-3.6-he412f7d_0
#   numpy              conda-forge/linux-64::numpy-1.23.1-py310h53a5b5f_0
#   openh264           conda-forge/linux-64::openh264-2.1.1-h780b84a_0
#   openjpeg           conda-forge/linux-64::openjpeg-2.4.0-hb52868f_1
#   pillow             conda-forge/linux-64::pillow-9.2.0-py310he619898_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pytorch            pytorch/linux-64::pytorch-1.12.0-py3.10_cuda11.3_cudnn8.3.2_0
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   tbb                conda-forge/linux-64::tbb-2021.5.0-h924138e_1
#   torchaudio         pytorch/linux-64::torchaudio-0.12.0-py310_cu113
#   torchvision        pytorch/linux-64::torchvision-0.13.0-py310_cu113
#   typing_extensions  conda-forge/noarch::typing_extensions-4.3.0-pyha770c72_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.9-h7f98852_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#
# The following packages will be DOWNGRADED:
#
#   _openmp_mutex                                   4.5-2_gnu --> 4.5-2_kmp_llvm
#
#
#
# Downloading and Extracting Packages
# xorg-libxdmcp-1.1.3  | 19 KB     | ##################################### | 100%
# ffmpeg-4.3           | 9.9 MB    | ##################################### | 100%
# jpeg-9e              | 269 KB    | ##################################### | 100%
# nettle-3.6           | 6.5 MB    | ##################################### | 100%
# libpng-1.6.37        | 331 KB    | ##################################### | 100%
# liblapacke-3.9.0     | 12 KB     | ##################################### | 100%
# lcms2-2.12           | 443 KB    | ##################################### | 100%
# liblapack-3.9.0      | 12 KB     | ##################################### | 100%
# tbb-2021.5.0         | 1.9 MB    | ##################################### | 100%
# torchaudio-0.12.0    | 6.2 MB    | ##################################### | 100%
# libgfortran-ng-12.1. | 23 KB     | ##################################### | 100%
# openjpeg-2.4.0       | 444 KB    | ##################################### | 100%
# mkl-include-2022.1.0 | 745 KB    | ##################################### | 100%
# lame-3.100           | 496 KB    | ##################################### | 100%
# typing_extensions-4. | 28 KB     | ##################################### | 100%
# blas-2.115           | 13 KB     | ##################################### | 100%
# cudatoolkit-11.3.1   | 816.4 MB  | ##################################### | 100%
# openh264-2.1.1       | 1.5 MB    | ##################################### | 100%
# libgfortran5-12.1.0  | 1.8 MB    | ##################################### | 100%
# libtiff-4.4.0        | 638 KB    | ##################################### | 100%
# numpy-1.23.1         | 7.0 MB    | ##################################### | 100%
# mkl-2022.1.0         | 199.6 MB  | ##################################### | 100%
# freetype-2.10.4      | 890 KB    | ##################################### | 100%
# libdeflate-1.12      | 78 KB     | ##################################### | 100%
# gnutls-3.6.13        | 2.0 MB    | ##################################### | 100%
# mkl-devel-2022.1.0   | 25 KB     | ##################################### | 100%
# pillow-9.2.0         | 44.7 MB   | ##################################### | 100%
# pytorch-1.12.0       | 1.19 GB   | ##################################### | 100%
# xorg-libxau-1.0.9    | 13 KB     | ##################################### | 100%
# libxcb-1.13          | 391 KB    | ##################################### | 100%
# libwebp-1.2.3        | 96 KB     | ##################################### | 100%
# gmp-6.2.1            | 806 KB    | ##################################### | 100%
# giflib-5.2.1         | 77 KB     | ##################################### | 100%
# libblas-3.9.0        | 13 KB     | ##################################### | 100%
# lerc-3.0             | 216 KB    | ##################################### | 100%
# llvm-openmp-14.0.4   | 5.8 MB    | ##################################### | 100%
# pytorch-mutex-1.0    | 3 KB      | ##################################### | 100%
# _openmp_mutex-4.5    | 6 KB      | ##################################### | 100%
# pthread-stubs-0.4    | 5 KB      | ##################################### | 100%
# blas-devel-3.9.0     | 12 KB     | ##################################### | 100%
# libwebp-base-1.2.3   | 452 KB    | ##################################### | 100%
# libcblas-3.9.0       | 12 KB     | ##################################### | 100%
# torchvision-0.13.0   | 28.3 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: \ By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %cd ../..
# Out:
# /home/jovyan/work

# %%
# !git clone https://github.com/sithu31296/semantic-segmentation
# %cd semantic-segmentation
# %pip install -e .
# Out:
# Cloning into 'semantic-segmentation'...
# remote: Enumerating objects: 792, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 792 (delta 11), reused 39 (delta 11), pack-reused 753
# Receiving objects: 100% (792/792), 55.00 MiB | 19.10 MiB/s, done.
# Resolving deltas: 100% (462/462), done.
# /home/jovyan/work/semantic-segmentation
# Obtaining file:///home/jovyan/work/semantic-segmentation
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from semseg==0.4.1) (4.64.0)
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from semseg==0.4.1) (1.23.1)
# Collecting scipy
#   Downloading scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 20.5 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib
#   Downloading matplotlib-3.5.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 23.5 MB/s eta 0:00:0000:0100:01
# Collecting tensorboard
#   Downloading tensorboard-2.9.1-py3-none-any.whl (5.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.8/5.8 MB 23.8 MB/s eta 0:00:0000:0100:01
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20220512.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 22.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting rich
#   Downloading rich-12.5.1-py3-none-any.whl (235 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.6/235.6 kB 20.2 MB/s eta 0:00:00
# Collecting yacs>=0.1.6
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (682 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 682.2/682.2 kB 18.7 MB/s eta 0:00:0000:01
# Collecting termcolor>=1.1
#   Downloading termcolor-1.1.0.tar.gz (3.9 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow in /opt/conda/lib/python3.10/site-packages (from fvcore->semseg==0.4.1) (9.2.0)
# Collecting iopath>=0.1.7
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 14.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->semseg==0.4.1) (3.0.9)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->semseg==0.4.1) (21.3)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->semseg==0.4.1) (2.8.2)
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.4.4-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 29.4 MB/s eta 0:00:00a 0:00:01
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.34.4-py3-none-any.whl (944 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 944.1/944.1 kB 29.0 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /opt/conda/lib/python3.10/site-packages (from rich->semseg==0.4.1) (2.12.0)
# Collecting commonmark<0.10.0,>=0.9.0
#   Downloading commonmark-0.9.1-py2.py3-none-any.whl (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.1/51.1 kB 18.3 MB/s eta 0:00:00
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.1-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.3/93.3 kB 20.6 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 21.7 MB/s eta 0:00:0000:01
# Collecting absl-py>=0.4
#   Downloading absl_py-1.2.0-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.4/123.4 kB 30.9 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.7.0,>=0.6.0
#   Downloading tensorboard_data_server-0.6.1-py3-none-manylinux2010_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 27.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.10/site-packages (from tensorboard->semseg==0.4.1) (0.37.1)
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Collecting protobuf<3.20,>=3.9.2
#   Downloading protobuf-3.19.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 29.7 MB/s eta 0:00:0000:01
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.9.1-py2.py3-none-any.whl (167 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.8/167.8 kB 44.9 MB/s eta 0:00:00
# Collecting grpcio>=1.24.3
#   Downloading grpcio-1.47.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 23.1 MB/s eta 0:00:00a 0:00:01
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.1.2-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.9/224.9 kB 22.9 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->semseg==0.4.1) (2.28.1)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard->semseg==0.4.1) (63.2.0)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 33.0 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.2.0-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: six>=1.9.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard->semseg==0.4.1) (1.16.0)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.8-py3-none-any.whl (39 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: typing_extensions in /opt/conda/lib/python3.10/site-packages (from iopath>=0.1.7->fvcore->semseg==0.4.1) (4.3.0)
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->semseg==0.4.1) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->semseg==0.4.1) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->semseg==0.4.1) (1.26.10)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard->semseg==0.4.1) (3.3)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 25.0 MB/s eta 0:00:00
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->semseg==0.4.1) (3.2.0)
# Building wheels for collected packages: fvcore, iopath, termcolor
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20220512-py3-none-any.whl size=61263 sha256=8d589f2951666334eeabc519eb89718511deebe450b42b2c271328f72ac98882
#   Stored in directory: /home/jovyan/.cache/pip/wheels/c7/8f/c9/1da09aeb3f6ffbc1835fea895c84268a23124e085759da5031
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=6b82c67d80f441be86bd76385c0e198006d21a9adcebce2d404ecf0a1a0ee58d
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9a/a3/b6/ac0fcd1b4ed5cfeb3db92e6a0e476cfd48ed0df92b91080c1d
#   Building wheel for termcolor (setup.py) ... done
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=f332279d0f7d9705b50c3a739adbe864164ba1f197fcae6f99e26fc1402b14b5
#   Stored in directory: /home/jovyan/.cache/pip/wheels/a1/49/46/1b13a65d8da11238af9616b00fdde6d45b0f95d9291bac8452
# Successfully built fvcore iopath termcolor
# Installing collected packages: termcolor, tensorboard-plugin-wit, pyasn1, einops, commonmark, werkzeug, tensorboard-data-server, tabulate, scipy, rsa, rich, pyyaml, pyasn1-modules, protobuf, portalocker, markdown, kiwisolver, grpcio, fonttools, cycler, cachetools, absl-py, yacs, requests-oauthlib, matplotlib, iopath, google-auth, google-auth-oauthlib, fvcore, tensorboard, semseg
#   Running setup.py develop for semseg
# Successfully installed absl-py-1.2.0 cachetools-5.2.0 commonmark-0.9.1 cycler-0.11.0 einops-0.4.1 fonttools-4.34.4 fvcore-0.1.5.post20220512 google-auth-2.9.1 google-auth-oauthlib-0.4.6 grpcio-1.47.0 iopath-0.1.10 kiwisolver-1.4.4 markdown-3.4.1 matplotlib-3.5.2 portalocker-2.5.1 protobuf-3.19.4 pyasn1-0.4.8 pyasn1-modules-0.2.8 pyyaml-6.0 requests-oauthlib-1.3.1 rich-12.5.1 rsa-4.8 scipy-1.8.1 semseg-0.4.1 tabulate-0.8.10 tensorboard-2.9.1 tensorboard-data-server-0.6.1 tensorboard-plugin-wit-1.8.1 termcolor-1.1.0 werkzeug-2.1.2 yacs-0.1.8
# Note: you may need to restart the kernel to use updated packages.
